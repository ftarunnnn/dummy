# %% [markdown]
# # Notebook 01: Exploratory Data Analysis & Feature Engineering
# ### NeuroVision AI Suite
# This notebook explores the dataset distribution, feature correlations, and statistical summaries for tabular risk forecasting.

# %%
import numpy as np
import pandas as pd
from src.training.data_generator import generate_synthetic_tabular_data

# Load synthetic tabular risk dataset
df, X, y = generate_synthetic_tabular_data(n_samples=1000)
df.head()

# %%
# Summary statistics
df.describe()

# %%
# Target distribution count
df['Target_Risk'].value_counts()
